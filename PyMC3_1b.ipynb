# %% [markdown]
# # **Exercise 2 : Linear Regression**
#
# * produce an artificial DATA setrepresetnign 2 variables drawn from a NORMAL distribution corellated with each other by a simple linear relationship.
#
# * We will then fit a Linear Regression model, to ESTIMATE the coeffiient of X and the intercept.
#
# * We wil also introduce the concepts of 'ppc' Posterior Predictive checks'

# %%
# !pip install arviz==0.6.1
# !pip install pymc3==3.8
# !pip install Theano==1.0.4
# Out:
# Requirement already satisfied: arviz==0.6.1 in /usr/local/lib/python3.6/dist-packages (0.6.1)
# Requirement already satisfied: xarray>=0.11 in /usr/local/lib/python3.6/dist-packages (from arviz==0.6.1) (0.15.1)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.6/dist-packages (from arviz==0.6.1) (1.18.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from arviz==0.6.1) (20.4)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.6/dist-packages (from arviz==0.6.1) (1.1.4)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.6/dist-packages (from arviz==0.6.1) (1.4.1)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.6/dist-packages (from arviz==0.6.1) (1.5.4)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.6/dist-packages (from arviz==0.6.1) (3.2.2)
# Requirement already satisfied: setuptools>=41.2 in /usr/local/lib/python3.6/dist-packages (from xarray>=0.11->arviz==0.6.1) (50.3.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->arviz==0.6.1) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->arviz==0.6.1) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23->arviz==0.6.1) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23->arviz==0.6.1) (2.8.1)
# Requirement already satisfied: cftime in /usr/local/lib/python3.6/dist-packages (from netcdf4->arviz==0.6.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0->arviz==0.6.1) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0->arviz==0.6.1) (1.3.1)
# Requirement already satisfied: pymc3==3.8 in /usr/local/lib/python3.6/dist-packages (3.8)
# Requirement already satisfied: h5py>=2.7.0 in /usr/local/lib/python3.6/dist-packages (from pymc3==3.8) (2.10.0)
# Requirement already satisfied: arviz>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from pymc3==3.8) (0.6.1)
# Requirement already satisfied: pandas>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from pymc3==3.8) (1.1.4)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from pymc3==3.8) (1.4.1)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from pymc3==3.8) (1.18.5)
# Requirement already satisfied: tqdm>=4.8.4 in /usr/local/lib/python3.6/dist-packages (from pymc3==3.8) (4.41.1)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from pymc3==3.8) (0.5.1)
# Requirement already satisfied: theano>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from pymc3==3.8) (1.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py>=2.7.0->pymc3==3.8) (1.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from arviz>=0.4.1->pymc3==3.8) (20.4)
# Requirement already satisfied: xarray>=0.11 in /usr/local/lib/python3.6/dist-packages (from arviz>=0.4.1->pymc3==3.8) (0.15.1)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.6/dist-packages (from arviz>=0.4.1->pymc3==3.8) (1.5.4)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.6/dist-packages (from arviz>=0.4.1->pymc3==3.8) (3.2.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18.0->pymc3==3.8) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18.0->pymc3==3.8) (2018.9)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->arviz>=0.4.1->pymc3==3.8) (2.4.7)
# Requirement already satisfied: setuptools>=41.2 in /usr/local/lib/python3.6/dist-packages (from xarray>=0.11->arviz>=0.4.1->pymc3==3.8) (50.3.2)
# Requirement already satisfied: cftime in /usr/local/lib/python3.6/dist-packages (from netcdf4->arviz>=0.4.1->pymc3==3.8) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0->arviz>=0.4.1->pymc3==3.8) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0->arviz>=0.4.1->pymc3==3.8) (1.3.1)
# Requirement already satisfied: Theano==1.0.4 in /usr/local/lib/python3.6/dist-packages (1.0.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Theano==1.0.4) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Theano==1.0.4) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Theano==1.0.4) (1.4.1)

# %%
# %matplotlib inline
import pymc3 as pm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %config InlineBackend.figure_formats = ['retina']
plt.rc('font', size=12)
plt.style.use('seaborn-darkgrid')

# %% [markdown]
# First, we generate some data X which is drawn form a simple NORMAL distribution with mean $\mu = 1$ and sd $\sigma = 0.1$.
#
# We also add amodel NOISE also drawn from a NORMAL distriution with mean 0 and sd 0.1.
#
# and the obs_y is defined as
#
# ```
# obs_y = (2 * X) + 1 + noise
# ```
# The Goal of the MODEL is to reverse engineer the beta co efficient and what is the alpha intercept.

# %%
 #1. generate the artificial dataset.
N = 5000

noise = np.random.normal(0.0, 0.1, N)
X = np.random.normal(1.0, 0.1, N)
obs_y = (2 * X) + 1 + noise     # obs_y = ( beta*X) _ intercept + noise

# %% [markdown]
# We EXPECT that y  follows a NORMAL distribution
#
# ```
# y = pm.Normal('y', mu=expected_value, sd=stdev, observed=obs_y)
# ```
# we link it to th observed data ' obs_y'. Now we are not just fitting data but we also care about the way two variables are related. This is acieved by defining the mean  mu of y as the expectd_value
#
# ```
# expected_value = (X * coeff) + intercept
# ```
# We will try to estimate the coeff and the intercept . the stdev parameter represents the noise here.
#
# Again, like ususal the PRIOR on stdev is HalfNormal. The intercept can be positive or negative.

# %%
# 2. model that data with a simple regression model
with pm.Model() as exercise2:

#Priors
    stdev = pm.HalfNormal('stdev', sd=10)
    intercept = pm.Normal('intercept', mu=0.0, sd=10)
    coeff = pm.Normal('coeff', mu=0.5, sd=10)

#Deterministic
    expected_value = (X * coeff) + intercept
#Likelihood
    y = pm.Normal('y', mu=expected_value, sd=stdev, observed=obs_y)

    trace = pm.sample(1000)    # fit the data

    pm.traceplot((trace), ['intercept','coeff','stdev']) # plot the trace
    plt.show()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [coeff, intercept, stdev]
# Sampling chain 0, 0 divergences: 100%|██████████| 1500/1500 [00:12<00:00, 121.85it/s]
# Sampling chain 1, 0 divergences: 100%|██████████| 1500/1500 [00:13<00:00, 111.56it/s]
# The acceptance probability does not match the target. It is 0.9030953089575764, but should be close to 0.8. Try to increase the number of tuning steps.
# /usr/local/lib/python3.6/dist-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /usr/local/lib/python3.6/dist-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /usr/local/lib/python3.6/dist-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /usr/local/lib/python3.6/dist-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /usr/local/lib/python3.6/dist-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /usr/local/lib/python3.6/dist-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"

# %%
  pm.summary(trace)
# Out:
#             mean     sd  hpd_3%  hpd_97%  ...  ess_sd  ess_bulk  ess_tail  r_hat
# intercept  0.998  0.015   0.969    1.027  ...   679.0     687.0     588.0    1.0
# coeff      2.000  0.015   1.970    2.028  ...   678.0     685.0     600.0    1.0
# stdev      0.100  0.001   0.098    0.102  ...   743.0     742.0     729.0    1.0
#
# [3 rows x 11 columns]

# %% [markdown]
# intercept which was estimated to be aroud 1 looks correct, the Beta ( coeff)which was estimated around 2 looks correct as well and the stdev which is the noise in the model estimated as 0.1 also checks.

# %% [markdown]
# **Predictions** . Now we have a MODEL and lets try and make predictions based on the same training data. In the net exercise we can show how to do predictions on out of sample DATA i.e. using new data.
#
# **Important Point** :  we take the MEAN of each 1000 data point on axis = 0 of y_preds

# %%
# predictions suinf TRAINING data for now
with exercise2:

    ppc= pm.sample_posterior_predictive(trace, samples= 1000) # NOTE this will be deprecated and to be replace with sample_posterior_predictive

    # for each of values of X we will get 1000 estimates slightly different due to uncertainty of the mean of the parameters.
    y_preds = ppc['y']
    print( "y_preds shape = ", ppc['y'].shape)

    # Same thing, but now using the expectation
    expected_y_pred = np.reshape(np.mean(y_preds, axis=0), [-1])
# Out:
# /usr/local/lib/python3.6/dist-packages/pymc3/sampling.py:1247: UserWarning: samples parameter is smaller than nchains times ndraws, some draws and/or chains may not be represented in the returned posterior predictive sample
#   "samples parameter is smaller than nchains times ndraws, some draws "
# 100%|██████████| 1000/1000 [00:01<00:00, 663.36it/s]
# y_preds shape =  (1000, 5000)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X, expected_y_pred, c='g')    # estimates  of the Regression lines.
plt.scatter(X, obs_y, c='b', alpha=0.1)  # Blue is the actual DATA 
plt.title("Relationship between X and (predicted) Y")
plt.xlabel("X")
plt.ylabel("Y")

plt.show()
